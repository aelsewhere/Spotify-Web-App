# %% [markdown]
# # Generate Emotion Table!

# %%
# add imports
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import json
import os

# import spotipy
import spotipy

# %% [markdown]
# I am going to make an emotions table. Each row is a unique emotion. Each emotion will be a selectable option by the user. Each emotion will belong to a family, this will dictate the color of the emotion button. Each emotion will also have an intensity, this will dictate the opacity of the button.
#
# There are 18 different families.

# %% [markdown]
# | Emotion               | Family 1                  | Family 2               | Intensity              |
# |-----------------------|---------------------------|------------------------|------------------------|
# | Calm                  | Accepting                 | Tender                 | 2                      |
# | Centered              | Accepting                 |                        | 2                      |
# | Content               | Accepting                 |                        | 3                      |
# | Fulfilled             | Accepting                 | Loving                 | 4                      |
# | Patient               | Accepting                 |                        | 3                      |
# | Peaceful              | Accepting                 |                        | 2                      |
# | Present               | Accepting                 | Loving                 | 3                      |
# | Relaxed               | Accepting                 |                        | 2                      |
# | Serene                | Accepting                 | Tender                 | 2                      |
# | Trusting              | Accepting                 | Hopeful                | 3                      |
# | Open                  | Accepting                 |                        | 3                      |
# | Accepting             | Accepting                 | Loving                 | 3                      |
# | Amazed                | Joy                       |                        | 4                      |
# | Awe                   | Joy                       |                        | 4                      |
# | Bliss                 | Joy                       |                        | 5                      |
# | Delighted             | Joy                       | Grateful               | 4                      |
# | Eager                 | Joy                       |                        | 3                      |
# | Ecstatic              | Joy                       |                        | 5                      |
# | Enchanted             | Joy                       |                        | 4                      |
# | Energized             | Joy                       |                        | 4                      |
# | Engaged               | Joy                       | Curious                | 4                      |
# | Enthusiastic          | Joy                       |                        | 4                      |
# | Excited               | Joy                       |                        | 5                      |
# | Free                  | Joy                       | Courageous             | 4                      |
# | Happy                 | Joy                       |                        | 4                      |
# | Inspired              | Joy                       |                        | 4                      |
# | Invigorated           | Joy                       |                        | 4                      |
# | Lively                | Joy                       |                        | 4                      |
# | Passionate            | Joy                       |                        | 5                      |
# | Playful               | Joy                       |                        | 4                      |
# | Radiant               | Joy                       |                        | 4                      |
# | Refreshed             | Joy                       |                        | 3                      |
# | Rejuvenated           | Joy                       |                        | 3                      |
# | Renewed               | Joy                       |                        | 3                      |
# | Satisfied             | Joy                       |                        | 3                      |
# | Thrilled              | Joy                       |                        | 5                      |
# | Aliveness             | Joy                       |                        | 4                      |
# | Joy                   | Joy                       |                        | 5                      |
# | Vibrant               | Joy                       |                        | 4                      |
# | Agitated              | Angry                     |                        | 3                      |
# | Aggravated            | Angry                     |                        | 3                      |
# | Bitter                | Angry                     |                        | 3                      |
# | Contempt              | Angry                     |                        | 3                      |
# | Cynical               | Angry                     |                        | 3                      |
# | Disdain               | Angry                     |                        | 3                      |
# | Disgruntled           | Angry                     |                        | 3                      |
# | Disturbed             | Angry                     | Doubt                  | 3                      |
# | Edgy                  | Angry                     | Stressed               | 3                      |
# | Exasperated           | Angry                     |                        | 4                      |
# | Frustrated            | Angry                     |                        | 4                      |
# | Optimistic            | Hopeful                   |                        | 4                      |
# | Powerless             | Powerless                 |                        | 4                      |
# | Impotent              | Powerless                 |                        | 4                      |
# | Incapable             | Powerless                 |                        | 4                      |
# | Resigned              | Powerless                 |                        | 4                      |
# | Trapped               | Powerless                 |                        | 4                      |
# | Victim                | Powerless                 |                        | 4                      |
# | Tender                | Tender                    |                        | 4                      |
# | Reflective            | Tender                    |                        | 3                      |
# | Self-loving           | Tender                    |                        | 4                      |
# | Vulnerable            | Tender                    |                        | 4                      |
# | Burned out            | Stressed                  |                        | 4                      |
# | Cranky                | Stressed                  |                        | 3                      |
# | Depleted              | Stressed                  |                        | 4                      |
# | Exhausted             | Stressed                  |                        | 4                      |
# | Frazzled              | Stressed                  |                        | 4                      |
# | Overwhelm             | Stressed                  |                        | 4                      |
# | Rattled               | Stressed                  |                        | 4                      |
# | Rejecting             | Stressed                  | Doubt                  | 3                      |
# | Restless              | Stressed                  |                        | 3                      |
# | Shaken                | Stressed                  |                        | 4                      |
# | Tight                 | Stressed                  |                        | 3                      |
# | Worn out              | Stressed                  |                        | 4                      |
# | Stressed              | Stressed                  |                        | 4                      |
# | Tense                 | Stressed                  |                        | 4                      |
# | Concerned             | Doubt                     |                        | 3                      |
# | Dissatisfied          | Doubt                     |                        | 3                      |
# | Perplexed             | Doubt                     |                        | 3                      |
# | Questioning           | Doubt                     |                        | 3                      |
# | Reluctant             | Doubt                     |                        | 3                      |
# | Shocked               | Doubt                     |                        | 4                      |
# | Skeptical             | Doubt                     |                        | 3                      |
# | Suspicious            | Doubt                     |                        | 3                      |
# | Ungrounded            | Doubt                     |                        | 3                      |
# | Unsure                | Doubt                     |                        | 3                      |

# %% [markdown]
# Emotions gathered from [The Hoffman Institute](https://www.hoffmaninstitute.org/wp-content/uploads/Practices-FeelingsSensations.pdf). Copy & pasted this table above into a new file (emotion_table.md). This will make it easier to build the table.

# %%
emotes = pd.read_csv('emotion_table.md', sep='|', skipinitialspace=True)
# delete row 0 (-------- row)
emotes = emotes.drop(0)
emotes = emotes.drop(columns=['Unnamed: 0', 'Unnamed: 5'])
emotes.columns = emotes.columns.str.strip()

# %%
emotes
# Out:
#                     Emotion                    Family 1  \
# 1    Calm                    Accepting
# 2    Centered                Accepting
# 3    Content                 Accepting
# 4    Fulfilled               Accepting
# 5    Patient                 Accepting
# ..                      ...                         ...
# 202  Shocked                 Doubt
# 203  Skeptical               Doubt
# 204  Suspicious              Doubt
# 205  Ungrounded              Doubt
# 206  Unsure                  Doubt
#
#                     Family 2                Intensity
# 1    Tender                   2
# 2                        NaN  2
# 3                        NaN  3
# 4    Loving                   4
# 5                        NaN  3
# ..                       ...                      ...
# 202                      NaN  4
# 203                      NaN  3
# 204                      NaN  3
# 205                      NaN  3
# 206                      NaN  3
#
# [206 rows x 4 columns]
